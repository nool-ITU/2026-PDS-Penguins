# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
features_final = pd.read_csv("../../data/extracted_features_baseline_mean.csv")
train_groups = ['a', 'b', 'c', 'd']
train_features = features_final[features_final['group_id'].isin(train_groups)]
testing_features = features_final[features_final['group_id']== "e"]
feature_cols = ["Asymmetry", "Compactness", "Convexity", "Multicolor", "red_pixels", "blue_pixels", "mean_red", "mean_blue", "Entropy", "Hue_Var", "Sat_Var", "Val_Var"]

train_df = train_features[feature_cols + ["Class"]].copy()
train_df["label"] = train_df["Class"].astype(int)
train_df = train_df.drop(columns=["Class"])

# %%
#all features

# %%
#Extract X, y, and groups (for GroupKFold)
# Training data (groups a–d)
X_train = train_features[feature_cols].values
y_train = train_features["Class"].astype(int).values
groups_train = train_features["group_id"].values   # a, b, c, d

# Testing data (group e)
X_test = testing_features[feature_cols].values
y_test = testing_features["Class"].astype(int).values

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GroupKFold, GridSearchCV
import numpy as np

# 1. Random Forest model
rf = RandomForestClassifier(
    random_state=42,
    n_jobs=-1
)

# %%
# 2. Pipeline (no SFS, no scaler)
pipe = Pipeline([
    ("rf", rf)
])

# %%
# 3. Correct param grid (NO feature_selector)
param_grid = {
    "rf__n_estimators": [200, 300, 500],
    "rf__max_depth": [None, 5, 10, 20],
    "rf__min_samples_split": [2, 5, 10],
    "rf__min_samples_leaf": [1, 2, 4]
}

# %%
# 4. GroupKFold
cv = GroupKFold(n_splits=4)

# %%
# 5. GridSearchCV
grid = GridSearchCV(
    estimator=pipe,
    param_grid=param_grid,
    cv=cv,
    scoring="f1",
    n_jobs=-1,
    verbose=2,
    error_score=np.nan
)

grid.fit(X_train, y_train, groups=groups_train)

print("Best parameters:", grid.best_params_)
print("Best CV F1 score:", grid.best_score_)
# Out:
# Fitting 4 folds for each of 108 candidates, totalling 432 fits
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300; total time=   1.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300; total time=   1.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300; total time=   1.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300; total time=   1.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=300; total time=   1.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=300; total time=   1.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=300; total time=   1.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300; total time=   1.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300; total time=   1.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300; total time=   1.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300; total time=   1.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300; total time=   1.1s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=300; total time=   1.0s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=300; total time=   1.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.7s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.2s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.9s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.6s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.6s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.5s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=None, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.2s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.4s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.2s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.6s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.0s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500; total time=   0.9s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.0s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.6s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.2s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.6s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.0s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.0s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.1s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.1s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500; total time=   0.9s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.0s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.1s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.2s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.6s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.0s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.2s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.1s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=500; total time=   0.9s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.6s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.1s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.1s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.2s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.6s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.1s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.0s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.5s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.3s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.5s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.2s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.0s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=5, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300; total time=   1.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300; total time=   1.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.1s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.6s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.6s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.6s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=300; total time=   1.0s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.6s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.2s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=300; total time=   1.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.3s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=10, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300; total time=   1.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300; total time=   1.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=200; total time=   0.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=300; total time=   1.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.5s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=200; total time=   0.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=300; total time=   1.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=500; total time=   1.6s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=300; total time=   1.2s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=200; total time=   0.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=300; total time=   1.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.8s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=300; total time=   1.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=500; total time=   2.0s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.7s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=300; total time=   0.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=500; total time=   1.9s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.3s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.4s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=500; total time=   1.1s
# [CV] END rf__max_depth=20, rf__min_samples_leaf=4, rf__min_samples_split=10, rf__n_estimators=500; total time=   0.9s
# Best parameters: {'rf__max_depth': 5, 'rf__min_samples_leaf': 4, 'rf__min_samples_split': 2, 'rf__n_estimators': 200}
# Best CV F1 score: 0.6048660914817827

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# Best model from GridSearchCV
best_model = grid.best_estimator_

# Predictions on the test set
y_pred = best_model.predict(X_test)
y_prob = best_model.predict_proba(X_test)[:, 1]

from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score

def print_metrics(y_test, y_pred, y_prob):
    accuracy = accuracy_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    auc = roc_auc_score(y_test, y_prob)

    print(f"Accuracy: {accuracy:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"AUC: {auc:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"F1 Score: {f1:.4f}")

print_metrics(y_test, y_pred, y_prob)
# Confusion Matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

# Classification Report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# AUC Score
print("\nAUC:", roc_auc_score(y_test, y_prob))
# Out:
# Accuracy: 0.5121
# Recall: 0.6667
# AUC: 0.5148
# Precision: 0.5263
# F1 Score: 0.5882
# Confusion Matrix:
# [[ 61 117]
#  [ 65 130]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.48      0.34      0.40       178
#            1       0.53      0.67      0.59       195
#
#     accuracy                           0.51       373
#    macro avg       0.51      0.50      0.49       373
# weighted avg       0.51      0.51      0.50       373
#
#
# AUC: 0.5148372227023912

# %%
malignant_probs = y_prob[y_test == 1]
benign_probs = y_prob[y_test == 0]

plt.hist(benign_probs, bins=20, alpha=0.6, label="Benign (0)", color="blue")
plt.hist(malignant_probs, bins=20, alpha=0.6, label="Malignant (1)", color="red")

plt.xlabel("Predicted probability")
plt.ylabel("Count")
plt.title("Probability Distribution by True Class")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(y_prob, bins=20, color='purple', alpha=0.7)
plt.xlabel("Predicted probability of being malignant")
plt.ylabel("Count")
plt.title("Random Forest — Probability Distribution")
plt.grid(True)
plt.show()

# %%
#select the best features

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, roc_auc_score
import numpy as np

# 1. Get feature importances from your best RF
best_model = grid.best_estimator_
rf = best_model.named_steps["rf"]

importances = rf.feature_importances_

# 2. Rank features by importance
feature_ranking = sorted(
    zip(feature_cols, importances),
    key=lambda x: x[1],
    reverse=True
)

# 3. Try k = 1 to 12 and evaluate each model
results = []

for k in range(1, len(feature_cols) + 1):
    top_k_features = [feat for feat, imp in feature_ranking[:k]]
    
    X_train_k = train_features[top_k_features].values
    X_test_k = testing_features[top_k_features].values
    
    rf_k = RandomForestClassifier(
        random_state=42,
        n_jobs=-1
    )
    
    rf_k.fit(X_train_k, y_train)
    y_prob_k = rf_k.predict_proba(X_test_k)[:, 1]
    
    auc_k = roc_auc_score(y_test, y_prob_k)
    f1_k = f1_score(y_test, (y_prob_k >= 0.5).astype(int))
    
    results.append((k, auc_k, f1_k))

# 4. Convert to array for easy processing
results = np.array(results, dtype=object)

# 5. Find best k based on AUC
best_idx = np.argmax(results[:, 1])
best_k = results[best_idx, 0]
best_auc = results[best_idx, 1]
best_f1 = results[best_idx, 2]

print("Best k:", best_k)
print("Best AUC:", best_auc)
print("Best F1:", best_f1)

# 6. Get the final selected features
final_features = [feat for feat, imp in feature_ranking[:best_k]]
print("Selected features:", final_features)
# Out:
# Best k: 1
# Best AUC: 0.5177326418899453
# Best F1: 0.4972972972972973
# Selected features: ['Asymmetry']

# %%
# Prepare data with selected features
X_train_final = train_features[final_features].values
X_test_final = testing_features[final_features].values

# Train final RF
rf_final = RandomForestClassifier(
    random_state=42,
    n_jobs=-1
)

rf_final.fit(X_train_final, y_train)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
y_prob_final = rf_final.predict_proba(X_test_final)[:, 1]

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# Default threshold 0.5
y_pred_final = (y_prob_final >= 0.5).astype(int)

from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score

def print_metrics(y_test, y_pred, y_prob):
    accuracy = accuracy_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    auc = roc_auc_score(y_test, y_prob)

    print(f"Accuracy: {accuracy:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"AUC: {auc:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"F1 Score: {f1:.4f}")

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_final))

print("\nClassification Report:")
print(classification_report(y_test, y_pred_final))

print("\nAUC:", roc_auc_score(y_test, y_prob_final))
# Out:
# Confusion Matrix:
# [[ 95  83]
#  [103  92]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.48      0.53      0.51       178
#            1       0.53      0.47      0.50       195
#
#     accuracy                           0.50       373
#    macro avg       0.50      0.50      0.50       373
# weighted avg       0.50      0.50      0.50       373
#
#
# AUC: 0.5177326418899453

# %%
malignant_probs = y_prob_final[y_test == 1]
benign_probs = y_prob_final[y_test == 0]

plt.hist(benign_probs, bins=20, alpha=0.6, label="Benign (0)", color="blue")
plt.hist(malignant_probs, bins=20, alpha=0.6, label="Malignant (1)", color="red")

plt.xlabel("Predicted probability")
plt.ylabel("Count")
plt.title("Probability Distribution by True Class")
plt.legend()
plt.grid(True)
plt.show()
