# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
features_final = pd.read_csv("../../data/extracted_features_extended_mean.csv")
train_groups = ['a', 'b', 'c', 'd']
train_features = features_final[features_final['group_id'].isin(train_groups)]
testing_features = features_final[features_final['group_id']== "e"]
feature_cols = ["Asymmetry", "Compactness", "Convexity", "Multicolor", "red_pixels", "blue_pixels", "mean_red", "mean_blue", "Entropy", "Hue_Var", "Sat_Var", "Val_Var","2_3_lesions", "hair_feature"]

train_df = train_features[feature_cols + ["Class"]].copy()
train_df["label"] = train_df["Class"].astype(int)
train_df = train_df.drop(columns=["Class"])

# %%
#Extract X, y, and groups (for GroupKFold)
# Training data (groups a–d)
X_train = train_features[feature_cols].values
y_train = train_features["Class"].astype(int).values
groups_train = train_features["group_id"].values   # a, b, c, d

# Testing data (group e)
X_test = testing_features[feature_cols].values
y_test = testing_features["Class"].astype(int).values

# %%
#kNN model
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.pipeline import Pipeline

# Base model
knn = KNeighborsClassifier()

# STEP 2: Build the pipeline
pipe = Pipeline([
    ("scaler", StandardScaler()),  # Step 1: scale features for kNN
    ("feature_selector", SequentialFeatureSelector(
        knn,
        direction="forward",        # add features one by one
        n_features_to_select="auto" # will be overridden by GridSearchCV
    )),
    ("knn", knn)                   # Step 3: the actual classifier
])

# %%
# Fit the pipeline on your training data
pipe.fit(X_train, y_train)

# Extract the feature selector
selector = pipe.named_steps["feature_selector"]

# Boolean mask of selected features
mask = selector.get_support()

# Print selected feature names
selected_features = [f for f, m in zip(feature_cols, mask) if m]
print("Selected features:", selected_features)
# Out:
# Selected features: ['Asymmetry', 'Compactness', 'red_pixels', 'blue_pixels', 'Entropy', 'Hue_Var', '2_3_lesions']

# %%
# STEP 3: Define the hyperparameter grid for GridSearchCV

param_grid = {
    "feature_selector__n_features_to_select": [4, 6, 8, 10, 12],
    "knn__n_neighbors": [3, 5, 7, 9, 11, 15],
    "knn__weights": ["uniform", "distance"],
    "knn__metric": ["euclidean", "manhattan"]
}

# %%
from sklearn.model_selection import GroupKFold, GridSearchCV

# STEP 4: GroupKFold cross-validation
cv = GroupKFold(n_splits=4)   # because you have groups a, b, c, d

# STEP 5: GridSearchCV with medical scoring
grid = GridSearchCV(
    estimator=pipe,                 # your pipeline from Step 2
    param_grid=param_grid,          # your grid from Step 3
    cv=cv,                          # GroupKFold
    scoring="f1",                   # medical: balances FN and FP
    n_jobs=-1,                      # use all CPU cores
    verbose=2                       # print progress
)

# Fit on training groups (a–d)
grid.fit(X_train, y_train, groups=groups_train)

print("Best parameters:", grid.best_params_)
print("Best CV F1 score:", grid.best_score_)
# Out:
# Fitting 4 folds for each of 120 candidates, totalling 480 fits
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   0.4s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   0.4s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   0.4s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   0.4s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   0.4s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   0.4s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   0.5s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   0.5s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   0.5s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   0.5s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   0.6s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   0.6s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   0.6s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   0.5s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   0.6s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   0.6s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   0.6s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   0.6s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   0.6s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   0.6s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   0.6s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   0.6s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   0.5s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   0.6s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   0.6s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   0.6s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   0.5s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   0.6s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   0.6s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   0.6s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   0.6s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   0.7s[CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   0.7s
#
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   1.4s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   1.4s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   1.4s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.5s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.4s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.6s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   2.2s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   2.3s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   2.3s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   2.3s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   2.2s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   2.5s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   2.6s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   2.7s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   2.6s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   2.4s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   2.5s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   2.5s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   2.5s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   2.7s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   2.6s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   2.7s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   2.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   3.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   3.3s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   3.3s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   4.7s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   4.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   5.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   5.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   5.6s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   5.8s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   6.2s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   6.5s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   6.3s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   6.3s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   6.4s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   6.4s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   7.2s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   6.5s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   6.2s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   7.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   6.2s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   6.2s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   6.3s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   6.6s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   6.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   6.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   6.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   5.6s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   6.2s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   6.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   5.7s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   5.7s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   6.2s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   6.6s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   6.3s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   6.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   6.6s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   6.7s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   6.8s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   6.6s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   6.5s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   6.6s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   7.2s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   7.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   7.4s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   8.3s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   7.7s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   8.2s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   7.7s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   8.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   7.3s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   7.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   7.7s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   8.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   7.8s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   7.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   6.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   7.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   7.3s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   7.3s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   7.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   7.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   6.5s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   7.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   5.5s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   5.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   5.5s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   5.5s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   4.7s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   4.5s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   3.8s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   4.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   2.6s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   2.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   1.2s
# ...
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   1.4s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   1.3s
# Best parameters: {'feature_selector__n_features_to_select': 12, 'knn__metric': 'euclidean', 'knn__n_neighbors': 11, 'knn__weights': 'distance'}
# Best CV F1 score: 0.5724494349268621

# %%
best_pipe = grid.best_estimator_

selector = best_pipe.named_steps["feature_selector"]
mask = selector.get_support()

selected_features = [f for f, m in zip(feature_cols, mask) if m]
print("Selected features:", selected_features)
print("Number of selected features:", sum(mask))

print("All final parameters:")
for param, value in best_pipe.get_params().items():
    print(param, ":", value)

print("Best hyperparameters:", grid.best_params_)

# Example: probability for class 1
probs = best_pipe.predict_proba(X_train)[:, 1]
print("Example probabilities:", probs[:10])

print(best_pipe)
# Out:
# Selected features: ['Asymmetry', 'Compactness', 'Convexity', 'Multicolor', 'red_pixels', 'blue_pixels', 'mean_red', 'mean_blue', 'Entropy', 'Hue_Var', 'Sat_Var', '2_3_lesions']
# Number of selected features: 12
# All final parameters:
# memory : None
# steps : [('scaler', StandardScaler()), ('feature_selector', SequentialFeatureSelector(estimator=KNeighborsClassifier(),
#                           n_features_to_select=12)), ('knn', KNeighborsClassifier(metric='euclidean', n_neighbors=11, weights='distance'))]
# transform_input : None
# verbose : False
# scaler : StandardScaler()
# feature_selector : SequentialFeatureSelector(estimator=KNeighborsClassifier(),
#                           n_features_to_select=12)
# knn : KNeighborsClassifier(metric='euclidean', n_neighbors=11, weights='distance')
# scaler__copy : True
# scaler__with_mean : True
# scaler__with_std : True
# feature_selector__cv : 5
# feature_selector__direction : forward
# feature_selector__estimator__algorithm : auto
# feature_selector__estimator__leaf_size : 30
# feature_selector__estimator__metric : minkowski
# feature_selector__estimator__metric_params : None
# feature_selector__estimator__n_jobs : None
# feature_selector__estimator__n_neighbors : 5
# feature_selector__estimator__p : 2
# feature_selector__estimator__weights : uniform
# feature_selector__estimator : KNeighborsClassifier()
# feature_selector__n_features_to_select : 12
# feature_selector__n_jobs : None
# feature_selector__scoring : None
# feature_selector__tol : None
# knn__algorithm : auto
# knn__leaf_size : 30
# knn__metric : euclidean
# knn__metric_params : None
# knn__n_jobs : None
# knn__n_neighbors : 11
# knn__p : 2
# knn__weights : distance
# Best hyperparameters: {'feature_selector__n_features_to_select': 12, 'knn__metric': 'euclidean', 'knn__n_neighbors': 11, 'knn__weights': 'distance'}
# Example probabilities: [1. 1. 0. 1. 0. 0. 0. 0. 1. 1.]
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('feature_selector',
#                  SequentialFeatureSelector(estimator=KNeighborsClassifier(),
#                                            n_features_to_select=12)),
#                 ('knn',
#                  KNeighborsClassifier(metric='euclidean', n_neighbors=11,
#                                       weights='distance'))])

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

best_model = grid.best_estimator_

y_pred = best_model.predict(X_test)
y_prob = best_model.predict_proba(X_test)[:, 1]

from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score

def print_metrics(y_test, y_pred, y_prob):
    accuracy = accuracy_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    auc = roc_auc_score(y_test, y_prob)

    print(f"Accuracy: {accuracy:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"AUC: {auc:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"F1 Score: {f1:.4f}")

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("\nAUC:", roc_auc_score(y_test, y_prob))
# Out:
# Confusion Matrix:
# [[ 81  97]
#  [ 79 116]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.51      0.46      0.48       178
#            1       0.54      0.59      0.57       195
#
#     accuracy                           0.53       373
#    macro avg       0.53      0.52      0.52       373
# weighted avg       0.53      0.53      0.53       373
#
#
# AUC: 0.5325842696629213

# %%
import matplotlib.pyplot as plt

plt.hist(y_prob, bins=20, color='purple', alpha=0.7)
plt.xlabel("Predicted probability of being malignant")
plt.ylabel("Count")
plt.title("Random Forest — Probability Distribution")
plt.grid(True)
plt.show()

# %%
malignant_probs = y_prob[y_test == 1]
benign_probs = y_prob[y_test == 0]

plt.hist(benign_probs, bins=20, alpha=0.6, label="Benign (0)", color="blue")
plt.hist(malignant_probs, bins=20, alpha=0.6, label="Malignant (1)", color="red")

plt.xlabel("Predicted probability")
plt.ylabel("Count")
plt.title("Probability Distribution by True Class")
plt.legend()
plt.grid(True)
plt.show()
