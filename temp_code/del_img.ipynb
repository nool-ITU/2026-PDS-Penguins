# %%
import pandas as pd

# %%
with open("img_delete.txt") as text:
    txt = text.read()
listy = txt.split(sep = "\n")

# %%
df = pd.read_csv("data_with_splits_updated.csv")
new_data = df[~df["img_id"].isin(listy)]
new_data
# Out:
#       Unnamed: 0.1  Unnamed: 0 patient_id  lesion_id  smoke  drink  \
# 0                0           0   PAT_1516       1765    NaN    NaN
# 1                1           1     PAT_46        881  False  False
# 2                2           2   PAT_1545       1867    NaN    NaN
# 3                3           3   PAT_1989       4061    NaN    NaN
# 4                4           4    PAT_684       1302  False   True
# ...            ...         ...        ...        ...    ...    ...
# 2098          2098        2289    PAT_386        785   True  False
# 2099          2099        2291    PAT_273        421  False  False
# 2100          2100        2292    PAT_491        934  False  False
# 2101          2101        2294     PAT_46        880  False  False
# 2102          2102        2296    PAT_326        690  False  False
#
#      background_father background_mother  age pesticide  ... diagnostic  \
# 0                  NaN               NaN    8       NaN  ...        NEV
# ...

# %%
new_data.to_csv("../data/clean_data.csv", index=False)

# %%
print(len(listy))
print(len(df[df["img_id"].isin(listy)]))
# Out:
# 310
# 238

# %%
# items in listy that are NOT present in df["img_id"]
missing = set(listy) - set(df["img_id"])
print(len(missing))
print(list(missing)[:10])
# Out:
# 10
# ['PAT_1402_1376_507.png', 'PAT_380_773_542.png', 'PAT_2161_4819_719.png', 'PAT_1371_1278_53.png', 'PAT_388_1590_518.png', 'PAT_181_12_158.png', 'PAT_277_36_814.png', 'PAT_999_20_401.png', 'PAT_970_92_270.png', 'PAT_1094_381_355.png']
