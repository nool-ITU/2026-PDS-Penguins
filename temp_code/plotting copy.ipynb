# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#pair plot
df=pd.read_csv("../data/extracted_features.csv")
df=df.drop(columns=["lesion_id", "patient_id", "filename"])
g = sns.pairplot(df, hue='Class', palette="Set1", height=3, diag_kind="hist")

g.fig.suptitle("Pairwise Feature Relationships by Class", y=1.05)

plt.show()

# %%
from sklearn.preprocessing import StandardScaler
 
# List of features I want to scale
features = ["Compactness","Asymmetry", "Convexity", "Multicolor", "Hue_Var", "Sat_Var", "Val_Var",]
object = StandardScaler()
 
#Create a copy of df
df_scaled = df.copy()
 
# standardization
df_scaled[features] = object.fit_transform(df[features])
df_scaled
# Out:
#       Asymmetry  Compactness  Convexity  Multicolor   Hue_Var   Sat_Var  \
# 0     -0.225001    -0.206808   0.139262   -0.182834 -0.329605  0.957153
# 1      0.337168    -0.015034  -0.161253   -1.014631 -0.299123  1.022139
# 2     -0.729439    -0.295361   0.556380   -0.179281  1.032612  0.097041
# 3      1.986945     0.174621  -1.441975   -1.483663 -0.233233 -0.612836
# 4     -0.035189    -0.239484   0.606210    0.863571 -0.306167  0.933562
# ...         ...          ...        ...         ...       ...       ...
# 1669   1.808679     0.552206  -1.682242    0.385883 -0.333651 -0.870679
# 1670  -0.103071    -0.011154   0.043993   -0.318112 -0.017950  0.133595
# 1671  -0.774827    -0.274982   0.516008   -0.483869 -0.149506  1.194728
# 1672   2.386375     0.296133  -2.574257    0.853366 -0.264585  0.034960
# 1673  -0.534452    -0.231447   0.515314   -0.122579 -0.322715 -0.002420
#
#        Val_Var  Class
# 0     1.196173   True
# 1    -0.123777   True
# 2    -0.086323   True
# ...

# %%
long_df = df_scaled.melt(
    id_vars="Class",
    var_name="feature",
    value_name="value"
)
long_df['value'] = pd.to_numeric(long_df['value'], errors='coerce')

# %%
plt.figure(figsize=(15, 30))
ax = sns.boxplot(data=long_df, x="feature", y="value", hue="Class", palette="Set1")
ax.set_title("Feature distribution by label")
# Out:
# Text(0.5, 1.0, 'Feature distribution by label')

# %%
# !pip install plotly

# %%
# !pip install nbformat

# %%
pip install nbformat --upgrade
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipywidgets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px

# Forza la colonna Class a stringa per avere colori netti
df['Class'] = df['Class'].astype(str) 

features = ["Compactness", "Asymmetry", "Convexity", "Multicolor", "Hue_Var", "Sat_Var", "Val_Var"]

fig = px.scatter_3d(
    df, 
    x="Compactness", 
    y="Asymmetry", 
    z="Convexity",
    color="Class",
    opacity=0.8,
    template="plotly_dark",
    title="Esploratore 3D - Punti Piccoli"
)

# --- QUI IMPOSTI LA DIMENSIONE DEI PUNTI ---
# size=2 o 3 è l'ideale per dataset densi
fig.update_traces(marker=dict(size=3, line=dict(width=0))) 

def create_buttons(axis_name):
    return [
        dict(
            method="restyle",
            args=[{axis_name: [df[f]]}],
            label=f
        ) for f in features
    ]

fig.update_layout(
    updatemenus=[
        dict(buttons=create_buttons("x"), direction="down", x=0.1, xanchor="left", y=1.1, yanchor="top"),
        dict(buttons=create_buttons("y"), direction="down", x=0.4, xanchor="left", y=1.1, yanchor="top"),
        dict(buttons=create_buttons("z"), direction="down", x=0.7, xanchor="left", y=1.1, yanchor="top")
    ]
)

fig.show()

# %%
pip install mlxtend
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import itertools
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder # Added for safe label conversion
from mlxtend.classifier import EnsembleVoteClassifier
from mlxtend.plotting import plot_decision_regions

# 1. Feature Selection
# Using .iloc to ensure we grab columns from the DataFrame by index
X_subset = df_scaled.iloc[:, [0, 3]].values

# 2. Target Variable Preparation
# LabelEncoder handles strings like 'True'/'False' or 'Cat'/'Dog' automatically
le = LabelEncoder()
y = le.fit_transform(df["Class"]) 

# 3. Initializing Classifiers
clf1 = LogisticRegression(random_state=0)
clf2 = RandomForestClassifier(random_state=0)
clf3 = KNeighborsClassifier(n_neighbors=7)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2, clf3],
                              weights=[1, 2, 1], voting='soft')

# 4. Plotting Setup
gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(10, 8))

labels = ['Logistic Regression', 'Random Forest', 'KNN (k=7)', 'Ensemble']

# 5. The Training and Plotting Loop
for clf, lab, grd in zip([clf1, clf2, clf3, eclf],
                         labels,
                         itertools.product([0, 1], repeat=2)):
    
    # Train the model
    clf.fit(X_subset, y)
    
    # Select the subplot
    ax = plt.subplot(gs[grd[0], grd[1]])
    
    # Plot the decision regions
    plot_decision_regions(X=X_subset, y=y, clf=clf, legend=2)
    
    plt.title(lab)
    plt.xlabel('Compactness')
    plt.ylabel('Multicolor')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import itertools
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder # Added for safe label conversion
from mlxtend.classifier import EnsembleVoteClassifier
from mlxtend.plotting import plot_decision_regions

# 1. Feature Selection
# Using .iloc to ensure we grab columns from the DataFrame by index
X_subset = df_scaled.iloc[:, [1, 3]].values

# 2. Target Variable Preparation
# LabelEncoder handles strings like 'True'/'False' or 'Cat'/'Dog' automatically
le = LabelEncoder()
y = le.fit_transform(df["Class"]) 

# 3. Initializing Classifiers
clf1 = LogisticRegression(random_state=0)
clf2 = RandomForestClassifier(random_state=0)
clf3 = KNeighborsClassifier(n_neighbors=7)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2, clf3],
                              weights=[1, 2, 1], voting='soft')

# 4. Plotting Setup
gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(10, 8))

labels = ['Logistic Regression', 'Random Forest', 'KNN (k=7)', 'Ensemble']

# 5. The Training and Plotting Loop
for clf, lab, grd in zip([clf1, clf2, clf3, eclf],
                         labels,
                         itertools.product([0, 1], repeat=2)):
    
    # Train the model
    clf.fit(X_subset, y)
    
    # Select the subplot
    ax = plt.subplot(gs[grd[0], grd[1]])
    
    # Plot the decision regions
    plot_decision_regions(X=X_subset, y=y, clf=clf, legend=2)
    
    plt.title(lab)
    plt.xlabel('Compactness')
    plt.ylabel('Multicolor')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import itertools
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder # Added for safe label conversion
from mlxtend.classifier import EnsembleVoteClassifier
from mlxtend.plotting import plot_decision_regions

# 1. Feature Selection
# Using .iloc to ensure we grab columns from the DataFrame by index
X_subset = df_scaled.iloc[:, [0, 4]].values

# 2. Target Variable Preparation
# LabelEncoder handles strings like 'True'/'False' or 'Cat'/'Dog' automatically
le = LabelEncoder()
y = le.fit_transform(df["Class"]) 

# 3. Initializing Classifiers
clf1 = LogisticRegression(random_state=0)
clf2 = RandomForestClassifier(random_state=0)
clf3 = KNeighborsClassifier(n_neighbors=7)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2, clf3],
                              weights=[1, 2, 1], voting='soft')

# 4. Plotting Setup
gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(10, 8))

labels = ['Logistic Regression', 'Random Forest', 'KNN (k=7)', 'Ensemble']

# 5. The Training and Plotting Loop
for clf, lab, grd in zip([clf1, clf2, clf3, eclf],
                         labels,
                         itertools.product([0, 1], repeat=2)):
    
    # Train the model
    clf.fit(X_subset, y)
    
    # Select the subplot
    ax = plt.subplot(gs[grd[0], grd[1]])
    
    # Plot the decision regions
    plot_decision_regions(X=X_subset, y=y, clf=clf, legend=2)
    
    plt.title(lab)
    plt.xlabel('Compactness')
    plt.ylabel('Multicolor')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import itertools
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder # Added for safe label conversion
from mlxtend.classifier import EnsembleVoteClassifier
from mlxtend.plotting import plot_decision_regions

# 1. Feature Selection
# Using .iloc to ensure we grab columns from the DataFrame by index
X_subset = df_scaled.iloc[:, [0, 1]].values

# 2. Target Variable Preparation
# LabelEncoder handles strings like 'True'/'False' or 'Cat'/'Dog' automatically
le = LabelEncoder()
y = le.fit_transform(df["Class"]) 

# 3. Initializing Classifiers
clf1 = LogisticRegression(random_state=0)
clf2 = RandomForestClassifier(random_state=0)
clf3 = KNeighborsClassifier(n_neighbors=7)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2, clf3],
                              weights=[1, 2, 1], voting='soft')

# 4. Plotting Setup
gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(10, 8))

labels = ['Logistic Regression', 'Random Forest', 'KNN (k=7)', 'Ensemble']

# 5. The Training and Plotting Loop
for clf, lab, grd in zip([clf1, clf2, clf3, eclf],
                         labels,
                         itertools.product([0, 1], repeat=2)):
    
    # Train the model
    clf.fit(X_subset, y)
    
    # Select the subplot
    ax = plt.subplot(gs[grd[0], grd[1]])
    
    # Plot the decision regions
    plot_decision_regions(X=X_subset, y=y, clf=clf, legend=2)
    
    plt.title(lab)
    plt.xlabel('Compactness')
    plt.ylabel('Multicolor')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import itertools
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder # Added for safe label conversion
from mlxtend.classifier import EnsembleVoteClassifier
from mlxtend.plotting import plot_decision_regions

# 1. Feature Selection
# Using .iloc to ensure we grab columns from the DataFrame by index
X_subset = df_scaled.iloc[:, [0, 4]].values

# 2. Target Variable Preparation
# LabelEncoder handles strings like 'True'/'False' or 'Cat'/'Dog' automatically
le = LabelEncoder()
y = le.fit_transform(df["Class"]) 

# 3. Initializing Classifiers
clf1 = LogisticRegression(random_state=0)
clf2 = RandomForestClassifier(random_state=0)
clf3 = KNeighborsClassifier(n_neighbors=7)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2, clf3],
                              weights=[1, 2, 1], voting='soft')

# 4. Plotting Setup
gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(10, 8))

labels = ['Logistic Regression', 'Random Forest', 'KNN (k=7)', 'Ensemble']

# 5. The Training and Plotting Loop
for clf, lab, grd in zip([clf1, clf2, clf3, eclf],
                         labels,
                         itertools.product([0, 1], repeat=2)):
    
    # Train the model
    clf.fit(X_subset, y)
    
    # Select the subplot
    ax = plt.subplot(gs[grd[0], grd[1]])
    
    # Plot the decision regions
    plot_decision_regions(X=X_subset, y=y, clf=clf, legend=2)
    
    plt.title(lab)
    plt.xlabel('Compactness')
    plt.ylabel('Multicolor')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import itertools
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder # Added for safe label conversion
from mlxtend.classifier import EnsembleVoteClassifier
from mlxtend.plotting import plot_decision_regions

# 1. Feature Selection
# Using .iloc to ensure we grab columns from the DataFrame by index
X_subset = df_scaled.iloc[:, [0, 5]].values

# 2. Target Variable Preparation
# LabelEncoder handles strings like 'True'/'False' or 'Cat'/'Dog' automatically
le = LabelEncoder()
y = le.fit_transform(df["Class"]) 

# 3. Initializing Classifiers
clf1 = LogisticRegression(random_state=0)
clf2 = RandomForestClassifier(random_state=0)
clf3 = KNeighborsClassifier(n_neighbors=7)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2, clf3],
                              weights=[1, 2, 1], voting='soft')

# 4. Plotting Setup
gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(10, 8))

labels = ['Logistic Regression', 'Random Forest', 'KNN (k=7)', 'Ensemble']

# 5. The Training and Plotting Loop
for clf, lab, grd in zip([clf1, clf2, clf3, eclf],
                         labels,
                         itertools.product([0, 1], repeat=2)):
    
    # Train the model
    clf.fit(X_subset, y)
    
    # Select the subplot
    ax = plt.subplot(gs[grd[0], grd[1]])
    
    # Plot the decision regions
    plot_decision_regions(X=X_subset, y=y, clf=clf, legend=2)
    
    plt.title(lab)
    plt.xlabel('Compactness')
    plt.ylabel('Multicolor')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import itertools
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder # Added for safe label conversion
from mlxtend.classifier import EnsembleVoteClassifier
from mlxtend.plotting import plot_decision_regions

# 1. Feature Selection
# Using .iloc to ensure we grab columns from the DataFrame by index
X_subset = df_scaled.iloc[:, [0, 6]].values

# 2. Target Variable Preparation
# LabelEncoder handles strings like 'True'/'False' or 'Cat'/'Dog' automatically
le = LabelEncoder()
y = le.fit_transform(df["Class"]) 

# 3. Initializing Classifiers
clf1 = LogisticRegression(random_state=0)
clf2 = RandomForestClassifier(random_state=0)
clf3 = KNeighborsClassifier(n_neighbors=7)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2, clf3],
                              weights=[1, 2, 1], voting='soft')

# 4. Plotting Setup
gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(10, 8))

labels = ['Logistic Regression', 'Random Forest', 'KNN (k=7)', 'Ensemble']

# 5. The Training and Plotting Loop
for clf, lab, grd in zip([clf1, clf2, clf3, eclf],
                         labels,
                         itertools.product([0, 1], repeat=2)):
    
    # Train the model
    clf.fit(X_subset, y)
    
    # Select the subplot
    ax = plt.subplot(gs[grd[0], grd[1]])
    
    # Plot the decision regions
    plot_decision_regions(X=X_subset, y=y, clf=clf, legend=2)
    
    plt.title(lab)
    plt.xlabel('Compactness')
    plt.ylabel('Multicolor')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import itertools
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder # Added for safe label conversion
from mlxtend.classifier import EnsembleVoteClassifier
from mlxtend.plotting import plot_decision_regions

# 1. Feature Selection
# Using .iloc to ensure we grab columns from the DataFrame by index
X_subset = df_scaled.iloc[:, [1, 4]].values

# 2. Target Variable Preparation
# LabelEncoder handles strings like 'True'/'False' or 'Cat'/'Dog' automatically
le = LabelEncoder()
y = le.fit_transform(df["Class"]) 

# 3. Initializing Classifiers
clf1 = LogisticRegression(random_state=0)
clf2 = RandomForestClassifier(random_state=0)
clf3 = KNeighborsClassifier(n_neighbors=7)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2, clf3],
                              weights=[1, 2, 1], voting='soft')

# 4. Plotting Setup
gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(10, 8))

labels = ['Logistic Regression', 'Random Forest', 'KNN (k=7)', 'Ensemble']

# 5. The Training and Plotting Loop
for clf, lab, grd in zip([clf1, clf2, clf3, eclf],
                         labels,
                         itertools.product([0, 1], repeat=2)):
    
    # Train the model
    clf.fit(X_subset, y)
    
    # Select the subplot
    ax = plt.subplot(gs[grd[0], grd[1]])
    
    # Plot the decision regions
    plot_decision_regions(X=X_subset, y=y, clf=clf, legend=2)
    
    plt.title(lab)
    plt.xlabel('Compactness')
    plt.ylabel('Multicolor')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import itertools
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder # Added for safe label conversion
from mlxtend.classifier import EnsembleVoteClassifier
from mlxtend.plotting import plot_decision_regions

# 1. Feature Selection
# Using .iloc to ensure we grab columns from the DataFrame by index
X_subset = df_scaled.iloc[:, [1, 5]].values

# 2. Target Variable Preparation
# LabelEncoder handles strings like 'True'/'False' or 'Cat'/'Dog' automatically
le = LabelEncoder()
y = le.fit_transform(df["Class"]) 

# 3. Initializing Classifiers
clf1 = LogisticRegression(random_state=0)
clf2 = RandomForestClassifier(random_state=0)
clf3 = KNeighborsClassifier(n_neighbors=7)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2, clf3],
                              weights=[1, 2, 1], voting='soft')

# 4. Plotting Setup
gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(10, 8))

labels = ['Logistic Regression', 'Random Forest', 'KNN (k=7)', 'Ensemble']

# 5. The Training and Plotting Loop
for clf, lab, grd in zip([clf1, clf2, clf3, eclf],
                         labels,
                         itertools.product([0, 1], repeat=2)):
    
    # Train the model
    clf.fit(X_subset, y)
    
    # Select the subplot
    ax = plt.subplot(gs[grd[0], grd[1]])
    
    # Plot the decision regions
    plot_decision_regions(X=X_subset, y=y, clf=clf, legend=2)
    
    plt.title(lab)
    plt.xlabel('Compactness')
    plt.ylabel('Multicolor')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import itertools
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder # Added for safe label conversion
from mlxtend.classifier import EnsembleVoteClassifier
from mlxtend.plotting import plot_decision_regions

# 1. Feature Selection
# Using .iloc to ensure we grab columns from the DataFrame by index
X_subset = df_scaled.iloc[:, [1, 6]].values

# 2. Target Variable Preparation
# LabelEncoder handles strings like 'True'/'False' or 'Cat'/'Dog' automatically
le = LabelEncoder()
y = le.fit_transform(df["Class"]) 

# 3. Initializing Classifiers
clf1 = LogisticRegression(random_state=0)
clf2 = RandomForestClassifier(random_state=0)
clf3 = KNeighborsClassifier(n_neighbors=7)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2, clf3],
                              weights=[1, 2, 1], voting='soft')

# 4. Plotting Setup
gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(10, 8))

labels = ['Logistic Regression', 'Random Forest', 'KNN (k=7)', 'Ensemble']

# 5. The Training and Plotting Loop
for clf, lab, grd in zip([clf1, clf2, clf3, eclf],
                         labels,
                         itertools.product([0, 1], repeat=2)):
    
    # Train the model
    clf.fit(X_subset, y)
    
    # Select the subplot
    ax = plt.subplot(gs[grd[0], grd[1]])
    
    # Plot the decision regions
    plot_decision_regions(X=X_subset, y=y, clf=clf, legend=2)
    
    plt.title(lab)
    plt.xlabel('Compactness')
    plt.ylabel('Multicolor')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import itertools
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder # Added for safe label conversion
from mlxtend.classifier import EnsembleVoteClassifier
from mlxtend.plotting import plot_decision_regions

# 1. Feature Selection
# Using .iloc to ensure we grab columns from the DataFrame by index
X_subset = df_scaled.iloc[:, [2, 3]].values

# 2. Target Variable Preparation
# LabelEncoder handles strings like 'True'/'False' or 'Cat'/'Dog' automatically
le = LabelEncoder()
y = le.fit_transform(df["Class"]) 

# 3. Initializing Classifiers
clf1 = LogisticRegression(random_state=0)
clf2 = RandomForestClassifier(random_state=0)
clf3 = KNeighborsClassifier(n_neighbors=7)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2, clf3],
                              weights=[1, 2, 1], voting='soft')

# 4. Plotting Setup
gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(10, 8))

labels = ['Logistic Regression', 'Random Forest', 'KNN (k=7)', 'Ensemble']

# 5. The Training and Plotting Loop
for clf, lab, grd in zip([clf1, clf2, clf3, eclf],
                         labels,
                         itertools.product([0, 1], repeat=2)):
    
    # Train the model
    clf.fit(X_subset, y)
    
    # Select the subplot
    ax = plt.subplot(gs[grd[0], grd[1]])
    
    # Plot the decision regions
    plot_decision_regions(X=X_subset, y=y, clf=clf, legend=2)
    
    plt.title(lab)
    plt.xlabel('Compactness')
    plt.ylabel('Multicolor')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import itertools
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder # Added for safe label conversion
from mlxtend.classifier import EnsembleVoteClassifier
from mlxtend.plotting import plot_decision_regions

# 1. Feature Selection
# Using .iloc to ensure we grab columns from the DataFrame by index
X_subset = df_scaled.iloc[:, [2, 4]].values

# 2. Target Variable Preparation
# LabelEncoder handles strings like 'True'/'False' or 'Cat'/'Dog' automatically
le = LabelEncoder()
y = le.fit_transform(df["Class"]) 

# 3. Initializing Classifiers
clf1 = LogisticRegression(random_state=0)
clf2 = RandomForestClassifier(random_state=0)
clf3 = KNeighborsClassifier(n_neighbors=7)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2, clf3],
                              weights=[1, 2, 1], voting='soft')

# 4. Plotting Setup
gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(10, 8))

labels = ['Logistic Regression', 'Random Forest', 'KNN (k=7)', 'Ensemble']

# 5. The Training and Plotting Loop
for clf, lab, grd in zip([clf1, clf2, clf3, eclf],
                         labels,
                         itertools.product([0, 1], repeat=2)):
    
    # Train the model
    clf.fit(X_subset, y)
    
    # Select the subplot
    ax = plt.subplot(gs[grd[0], grd[1]])
    
    # Plot the decision regions
    plot_decision_regions(X=X_subset, y=y, clf=clf, legend=2)
    
    plt.title(lab)
    plt.xlabel('Compactness')
    plt.ylabel('Multicolor')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import itertools
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder # Added for safe label conversion
from mlxtend.classifier import EnsembleVoteClassifier
from mlxtend.plotting import plot_decision_regions

# 1. Feature Selection
# Using .iloc to ensure we grab columns from the DataFrame by index
X_subset = df_scaled.iloc[:, [2, 5]].values

# 2. Target Variable Preparation
# LabelEncoder handles strings like 'True'/'False' or 'Cat'/'Dog' automatically
le = LabelEncoder()
y = le.fit_transform(df["Class"]) 

# 3. Initializing Classifiers
clf1 = LogisticRegression(random_state=0)
clf2 = RandomForestClassifier(random_state=0)
clf3 = KNeighborsClassifier(n_neighbors=7)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2, clf3],
                              weights=[1, 2, 1], voting='soft')

# 4. Plotting Setup
gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(10, 8))

labels = ['Logistic Regression', 'Random Forest', 'KNN (k=7)', 'Ensemble']

# 5. The Training and Plotting Loop
for clf, lab, grd in zip([clf1, clf2, clf3, eclf],
                         labels,
                         itertools.product([0, 1], repeat=2)):
    
    # Train the model
    clf.fit(X_subset, y)
    
    # Select the subplot
    ax = plt.subplot(gs[grd[0], grd[1]])
    
    # Plot the decision regions
    plot_decision_regions(X=X_subset, y=y, clf=clf, legend=2)
    
    plt.title(lab)
    plt.xlabel('Compactness')
    plt.ylabel('Multicolor')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import itertools
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder # Added for safe label conversion
from mlxtend.classifier import EnsembleVoteClassifier
from mlxtend.plotting import plot_decision_regions

# 1. Feature Selection
# Using .iloc to ensure we grab columns from the DataFrame by index
X_subset = df_scaled.iloc[:, [2, 6]].values

# 2. Target Variable Preparation
# LabelEncoder handles strings like 'True'/'False' or 'Cat'/'Dog' automatically
le = LabelEncoder()
y = le.fit_transform(df["Class"]) 

# 3. Initializing Classifiers
clf1 = LogisticRegression(random_state=0)
clf2 = RandomForestClassifier(random_state=0)
clf3 = KNeighborsClassifier(n_neighbors=7)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2, clf3],
                              weights=[1, 2, 1], voting='soft')

# 4. Plotting Setup
gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(10, 8))

labels = ['Logistic Regression', 'Random Forest', 'KNN (k=7)', 'Ensemble']

# 5. The Training and Plotting Loop
for clf, lab, grd in zip([clf1, clf2, clf3, eclf],
                         labels,
                         itertools.product([0, 1], repeat=2)):
    
    # Train the model
    clf.fit(X_subset, y)
    
    # Select the subplot
    ax = plt.subplot(gs[grd[0], grd[1]])
    
    # Plot the decision regions
    plot_decision_regions(X=X_subset, y=y, clf=clf, legend=2)
    
    plt.title(lab)
    plt.xlabel('Compactness')
    plt.ylabel('Multicolor')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import itertools
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from mlxtend.classifier import EnsembleVoteClassifier
from mlxtend.plotting import plot_decision_regions

# 1. Feature Selection
# Column 1: Compactness, Column 3: Multicolor
X_subset = df_scaled.iloc[:, [1, 3]].values

# 2. Target Variable Preparation
# Converts 'True'/'False' strings into 1s and 0s
le = LabelEncoder()
y = le.fit_transform(df["Class"]) 

# 3. Split data into Training (80%) and Testing (20%)
X_train, X_test, y_train, y_test = train_test_split(
    X_subset, y, test_size=0.2, random_state=42
)

# 4. Initializing Classifiers
clf1 = LogisticRegression(random_state=0)
clf2 = RandomForestClassifier(random_state=0, n_estimators=100)
clf3 = KNeighborsClassifier(n_neighbors=7)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2, clf3],
                              weights=[0, 1, 1], voting='soft')

# 5. Plotting & Accuracy Setup
gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(12, 10))
labels = ['Logistic Regression', 'Random Forest', 'KNN (k=7)', 'Ensemble']

# 6. The Training, Accuracy, and Plotting Loop
for clf, lab, grd in zip([clf1, clf2, clf3, eclf],
                         labels,
                         itertools.product([0, 1], repeat=2)):
    
    # Train the model on the training data
    clf.fit(X_train, y_train)
    
    # Predict on the test data to get accuracy
    y_pred = clf.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    
    # Print accuracy to the console
    print(f'{lab} Accuracy: {acc:.2%}')
    
    # Select the subplot
    ax = plt.subplot(gs[grd[0], grd[1]])
    
    # Plot the decision regions using the full dataset for visualization
    plot_decision_regions(X=X_subset, y=y, clf=clf, legend=2)
    
    # Add Title with Accuracy
    plt.title(f'{lab}\nAccuracy: {acc:.2%}')
    plt.xlabel('Compactness')
    plt.ylabel('Multicolor')

plt.tight_layout()
plt.show()
# Out:
# Logistic Regression Accuracy: 41.79%
# Random Forest Accuracy: 44.48%
# KNN (k=7) Accuracy: 45.67%
# Ensemble Accuracy: 44.48%

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import itertools
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from mlxtend.classifier import EnsembleVoteClassifier
from mlxtend.plotting import plot_decision_regions

# 1. Feature Selection
# Column 1: Compactness, Column 3: Multicolor
X_subset = df_scaled.iloc[:, [0, 3]].values

# 2. Target Variable Preparation
# Converts 'True'/'False' strings into 1s and 0s
le = LabelEncoder()
y = le.fit_transform(df["Class"]) 

# 3. Split data into Training (80%) and Testing (20%)
X_train, X_test, y_train, y_test = train_test_split(
    X_subset, y, test_size=0.2, random_state=42
)

# 4. Initializing Classifiers
clf1 = LogisticRegression(random_state=0)
clf2 = RandomForestClassifier(random_state=0, n_estimators=100)
clf3 = KNeighborsClassifier(n_neighbors=7)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2, clf3],
                              weights=[0, 1, 1], voting='soft')

# 5. Plotting & Accuracy Setup
gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(12, 10))
labels = ['Logistic Regression', 'Random Forest', 'KNN (k=7)', 'Ensemble']

# 6. The Training, Accuracy, and Plotting Loop
for clf, lab, grd in zip([clf1, clf2, clf3, eclf],
                         labels,
                         itertools.product([0, 1], repeat=2)):
    
    # Train the model on the training data
    clf.fit(X_train, y_train)
    
    # Predict on the test data to get accuracy
    y_pred = clf.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    
    # Print accuracy to the console
    print(f'{lab} Accuracy: {acc:.2%}')
    
    # Select the subplot
    ax = plt.subplot(gs[grd[0], grd[1]])
    
    # Plot the decision regions using the full dataset for visualization
    plot_decision_regions(X=X_subset, y=y, clf=clf, legend=2)
    
    # Add Title with Accuracy
    plt.title(f'{lab}\nAccuracy: {acc:.2%}')
    plt.xlabel('Compactness')
    plt.ylabel('Multicolor')

plt.tight_layout()
plt.show()
# Out:
# Logistic Regression Accuracy: 43.88%
# Random Forest Accuracy: 47.16%
# KNN (k=7) Accuracy: 47.16%
# Ensemble Accuracy: 48.36%
