# %%
import pandas as pd

# %%
df= pd.read_csv("../data/extracted_features_baseline.csv")

# %%
df
# Out:
#      patient_id  lesion_id               filename  Asymmetry  Compactness  \
# 0       PAT_431        850    PAT_431_850_472.png    0.19834    10.029848
# 1       PAT_759       1433   PAT_759_1433_973.png    0.09698     8.204131
# 2        PAT_86       1109    PAT_86_1109_306.png    0.24752    10.064621
# 3       PAT_355        732    PAT_355_732_102.png    0.23648     9.356164
# 4       PAT_365        751    PAT_365_751_709.png    0.15144    10.755980
# ...         ...        ...                    ...        ...          ...
# 1729   PAT_2017       4164  PAT_2017_4164_500.png    0.14456     9.970740
# 1730    PAT_572       1086   PAT_572_1086_130.png    0.22284    14.063679
# 1731   PAT_2048       4333   PAT_2048_4333_63.png    0.13616     9.521869
# 1732    PAT_253        384    PAT_253_384_607.png    0.07566     8.573423
# 1733    PAT_827       1598    PAT_827_1598_85.png    0.22318    11.461160
#
#       Convexity  Multicolor  red_pixels  blue_pixels    mean_red   mean_blue  \
# ...

# %%
df[df["filename"]=="PAT_86_131_107.png"]
#symmetrical
# Out:
#     patient_id  lesion_id            filename  Asymmetry  Compactness  \
# 608     PAT_86        131  PAT_86_131_107.png    0.27282    15.516634
#
#      Convexity  Multicolor  red_pixels  blue_pixels   mean_red   mean_blue  \
# 608   0.811041  138.999794   52.330522    13.260194  124.68335  114.022259
#
#       Entropy   Hue_Var   Sat_Var   Val_Var group_id  2_3_lesions  Class
# 608  2.749724  0.098935  0.000643  0.004076        c        False  False

# %%
df[df["filename"]=="PAT_191_294_629.png"]
#asymmetrical
# Out:
#     patient_id  lesion_id             filename  Asymmetry  Compactness  \
# 384    PAT_191        294  PAT_191_294_629.png    0.47018    23.396186
#
#      Convexity  Multicolor  red_pixels  blue_pixels    mean_red  mean_blue  \
# 384   0.778198  188.804682   82.571195      6.63282  109.759069  75.795518
#
#       Entropy   Hue_Var   Sat_Var   Val_Var group_id  2_3_lesions  Class
# 384  1.941768  0.079967  0.020537  0.016692        c        False   True

# %%
df[df["filename"]=="PAT_79_120_739.png"]
#
# Out:
#     patient_id  lesion_id            filename  Asymmetry  Compactness  \
# 979     PAT_79        120  PAT_79_120_739.png     0.2844    14.664987
#
#      Convexity  Multicolor  red_pixels  blue_pixels    mean_red  mean_blue  \
# 979   0.795229   35.384593       100.0          0.0  149.407291  74.979246
#
#       Entropy   Hue_Var   Sat_Var   Val_Var group_id  2_3_lesions  Class
# 979  0.252255  0.000492  0.000664  0.000122        b        False   True
