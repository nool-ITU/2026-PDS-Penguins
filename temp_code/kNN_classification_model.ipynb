# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
features_final = pd.read_csv("../data/extracted_features_mean.csv")
train_groups = ['a', 'b', 'c', 'd']
train_features = features_final[features_final['group_id'].isin(train_groups)]
testing_features = features_final[features_final['group_id']== "e"]
feature_cols = ["Asymmetry", "Compactness", "Convexity", "Multicolor", "red_pixels", "blue_pixels", "mean_red", "mean_blue", "Entropy", "Hue_Var", "Sat_Var", "Val_Var"]

train_df = train_features[feature_cols + ["Class"]].copy()
train_df["label"] = train_df["Class"].astype(int)
train_df = train_df.drop(columns=["Class"])

# %%
#Extract X, y, and groups (for GroupKFold)
# Training data (groups a–d)
X_train = train_features[feature_cols].values
y_train = train_features["Class"].astype(int).values
groups_train = train_features["group_id"].values   # a, b, c, d

# Testing data (group e)
X_test = testing_features[feature_cols].values
y_test = testing_features["Class"].astype(int).values

# %%
#kNN model
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.pipeline import Pipeline

# Base model
knn = KNeighborsClassifier()

# STEP 2: Build the pipeline
pipe = Pipeline([
    ("scaler", StandardScaler()),  # Step 1: scale features for kNN
    ("feature_selector", SequentialFeatureSelector(
        knn,
        direction="forward",        # add features one by one
        n_features_to_select="auto" # will be overridden by GridSearchCV
    )),
    ("knn", knn)                   # Step 3: the actual classifier
])

# %%
# Fit the pipeline on your training data
pipe.fit(X_train, y_train)

# Extract the feature selector
selector = pipe.named_steps["feature_selector"]

# Boolean mask of selected features
mask = selector.get_support()

# Print selected feature names
selected_features = [f for f, m in zip(feature_cols, mask) if m]
print("Selected features:", selected_features)
# Out:
# Selected features: ['Asymmetry', 'red_pixels', 'blue_pixels', 'mean_blue', 'Entropy', 'Val_Var']

# %%
# STEP 3: Define the hyperparameter grid for GridSearchCV

param_grid = {
    "feature_selector__n_features_to_select": [4, 6, 8, 10, 12],
    "knn__n_neighbors": [3, 5, 7, 9, 11, 15],
    "knn__weights": ["uniform", "distance"],
    "knn__metric": ["euclidean", "manhattan"]
}

# %%
from sklearn.model_selection import GroupKFold, GridSearchCV

# STEP 4: GroupKFold cross-validation
cv = GroupKFold(n_splits=4)   # because you have groups a, b, c, d

# STEP 5: GridSearchCV with medical scoring
grid = GridSearchCV(
    estimator=pipe,                 # your pipeline from Step 2
    param_grid=param_grid,          # your grid from Step 3
    cv=cv,                          # GroupKFold
    scoring="f1",                   # medical: balances FN and FP
    n_jobs=-1,                      # use all CPU cores
    verbose=2                       # print progress
)

# Fit on training groups (a–d)
grid.fit(X_train, y_train, groups=groups_train)

print("Best parameters:", grid.best_params_)
print("Best CV F1 score:", grid.best_score_)
# Out:
# Fitting 4 folds for each of 120 candidates, totalling 480 fits
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   0.6s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   0.6s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   0.7s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=4, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   0.8s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   0.9s
# [CV] END feature_selector__n_features_to_select=6, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   1.0s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.1s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   1.4s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   1.2s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   1.4s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   1.4s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   1.4s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   1.4s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   1.4s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   1.5s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   1.4s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   1.4s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   1.5s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   1.4s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   1.4s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   1.4s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   1.4s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   1.4s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   1.4s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   1.4s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=8, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   1.3s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.5s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.5s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.5s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.5s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.4s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.5s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=3, knn__weights=distance; total time=   1.6s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.5s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.6s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform; total time=   1.5s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.9s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   1.9s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   1.8s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance; total time=   2.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   1.8s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   2.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform; total time=   1.8s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   1.5s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   1.6s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   1.6s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   1.6s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   1.4s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   1.5s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   1.5s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   1.6s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   1.6s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   1.6s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   1.6s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   1.8s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   1.6s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   1.6s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   1.6s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   1.6s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   1.6s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   1.6s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   1.6s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   1.8s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   1.6s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   1.5s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   1.6s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   1.8s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   2.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   1.8s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   1.8s
# ...
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   1.9s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance; total time=   0.0s[CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   0.0s
#
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=uniform; total time=   0.0s[CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   0.0s
#
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=9, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=11, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   0.0s[CV] END feature_selector__n_features_to_select=12, knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance; total time=   0.0s
#
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=9, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=11, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   0.0s[CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   0.0s
#
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=12, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   0.0s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   1.9s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform; total time=   1.7s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   1.6s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   1.6s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   1.5s
# [CV] END feature_selector__n_features_to_select=10, knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance; total time=   1.5s
# /opt/anaconda3/envs/pdsproject/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:490: FitFailedWarning:
# 96 fits failed out of a total of 480.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 96 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/pdsproject/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/envs/pdsproject/lib/python3.12/site-packages/sklearn/base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pdsproject/lib/python3.12/site-packages/sklearn/pipeline.py", line 613, in fit
#     Xt = self._fit(X, y, routed_params, raw_params=params)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pdsproject/lib/python3.12/site-packages/sklearn/pipeline.py", line 547, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pdsproject/lib/python3.12/site-packages/joblib/memory.py", line 326, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pdsproject/lib/python3.12/site-packages/sklearn/pipeline.py", line 1484, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pdsproject/lib/python3.12/site-packages/sklearn/utils/_set_output.py", line 316, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pdsproject/lib/python3.12/site-packages/sklearn/base.py", line 910, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pdsproject/lib/python3.12/site-packages/sklearn/base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pdsproject/lib/python3.12/site-packages/sklearn/feature_selection/_sequential.py", line 256, in fit
#     raise ValueError("n_features_to_select must be < n_features.")
# ValueError: n_features_to_select must be < n_features.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/anaconda3/envs/pdsproject/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1137: UserWarning: One or more of the test scores are non-finite: [0.51658662 0.52648293 0.51415261 0.51216438 0.52543423 0.52486716
#  0.51901864 0.52681977 0.52446265 0.52317696 0.53347106 0.53668035
#  0.53091375 0.53277365 0.52225985 0.52025179 0.51881022 0.52314895
#  0.52069821 0.52067097 0.53254295 0.53071918 0.55639751 0.54669594
#  0.51776722 0.51924378 0.5334171  0.53251756 0.52163592 0.5307182
#  0.52110718 0.51952329 0.52718415 0.5224976  0.55061717 0.54858923
#  0.52320646 0.52447659 0.5369594  0.54203882 0.53419444 0.53467901
#  0.54301551 0.54011523 0.53399054 0.52650626 0.5238998  0.52439652
#  0.5078871  0.50611441 0.49755143 0.49624889 0.51714599 0.50471089
#  0.51536784 0.511411   0.53462899 0.5240878  0.55727401 0.54184965
#  0.49342995 0.49362471 0.51587389 0.51117795 0.52133741 0.51542831
#  0.51818788 0.50456221 0.53543043 0.52187308 0.55356286 0.54546762
#  0.50800748 0.50942961 0.49436673 0.49212264 0.4983743  0.49470121
#  0.50289374 0.4951805  0.5138821  0.50940125 0.51373662 0.50932214
#  0.50314918 0.50377153 0.51175329 0.50969277 0.52844025 0.52410963
#  0.53483544 0.53297468 0.54373806 0.53783042 0.5308145  0.5296108
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# Best parameters: {'feature_selector__n_features_to_select': 8, 'knn__metric': 'euclidean', 'knn__n_neighbors': 15, 'knn__weights': 'uniform'}
# Best CV F1 score: 0.5572740085694545

# %%
best_pipe = grid.best_estimator_

selector = best_pipe.named_steps["feature_selector"]
mask = selector.get_support()

selected_features = [f for f, m in zip(feature_cols, mask) if m]
print("Selected features:", selected_features)
print("Number of selected features:", sum(mask))

print("All final parameters:")
for param, value in best_pipe.get_params().items():
    print(param, ":", value)

print("Best hyperparameters:", grid.best_params_)

# Example: probability for class 1
probs = best_pipe.predict_proba(X_train)[:, 1]
print("Example probabilities:", probs[:10])

print(best_pipe)
# Out:
# Selected features: ['Asymmetry', 'Convexity', 'Multicolor', 'red_pixels', 'blue_pixels', 'mean_blue', 'Entropy', 'Val_Var']
# Number of selected features: 8
# All final parameters:
# memory : None
# steps : [('scaler', StandardScaler()), ('feature_selector', SequentialFeatureSelector(estimator=KNeighborsClassifier(),
#                           n_features_to_select=8)), ('knn', KNeighborsClassifier(metric='euclidean', n_neighbors=15))]
# transform_input : None
# verbose : False
# scaler : StandardScaler()
# feature_selector : SequentialFeatureSelector(estimator=KNeighborsClassifier(),
#                           n_features_to_select=8)
# knn : KNeighborsClassifier(metric='euclidean', n_neighbors=15)
# scaler__copy : True
# scaler__with_mean : True
# scaler__with_std : True
# feature_selector__cv : 5
# feature_selector__direction : forward
# feature_selector__estimator__algorithm : auto
# feature_selector__estimator__leaf_size : 30
# feature_selector__estimator__metric : minkowski
# feature_selector__estimator__metric_params : None
# feature_selector__estimator__n_jobs : None
# feature_selector__estimator__n_neighbors : 5
# feature_selector__estimator__p : 2
# feature_selector__estimator__weights : uniform
# feature_selector__estimator : KNeighborsClassifier()
# feature_selector__n_features_to_select : 8
# feature_selector__n_jobs : None
# feature_selector__scoring : None
# feature_selector__tol : None
# knn__algorithm : auto
# knn__leaf_size : 30
# knn__metric : euclidean
# knn__metric_params : None
# knn__n_jobs : None
# knn__n_neighbors : 15
# knn__p : 2
# knn__weights : uniform
# Best hyperparameters: {'feature_selector__n_features_to_select': 8, 'knn__metric': 'euclidean', 'knn__n_neighbors': 15, 'knn__weights': 'uniform'}
# Example probabilities: [0.6        0.53333333 0.53333333 0.53333333 0.6        0.53333333
#  0.73333333 0.46666667 0.66666667 0.4       ]
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('feature_selector',
#                  SequentialFeatureSelector(estimator=KNeighborsClassifier(),
#                                            n_features_to_select=8)),
#                 ('knn',
#                  KNeighborsClassifier(metric='euclidean', n_neighbors=15))])

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

best_model = grid.best_estimator_

y_pred = best_model.predict(X_test)
y_prob = best_model.predict_proba(X_test)[:, 1]

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("\nAUC:", roc_auc_score(y_test, y_prob))
# Out:
# Confusion Matrix:
# [[75 92]
#  [89 94]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.46      0.45      0.45       167
#            1       0.51      0.51      0.51       183
#
#     accuracy                           0.48       350
#    macro avg       0.48      0.48      0.48       350
# weighted avg       0.48      0.48      0.48       350
#
#
# AUC: 0.4852426294951081
